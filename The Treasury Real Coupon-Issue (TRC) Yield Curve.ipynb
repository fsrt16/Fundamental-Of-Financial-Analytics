# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %%
df = pd.read_csv('F.csv')
taget = 'target'
nrows , ncols = df.shape
df.head()
# Out:
#    YEAR  AVG avg_interest_among_all_matuarity
# 0  2013                              1.062846
# 1  2014                              1.104413
# 2  2015                              1.039117
# 3  2016                              0.906138
# 4  2017                              0.941758

# %%
df.describe()
# Out:
#               YEAR  AVG avg_interest_among_all_matuarity
# count     5.000000                              5.000000
# mean   2015.000000                              1.010854
# std       1.581139                              0.083658
# min    2013.000000                              0.906138
# 25%    2014.000000                              0.941758
# 50%    2015.000000                              1.039117
# 75%    2016.000000                              1.062846
# max    2017.000000                              1.104413

# %%
year = list(df['YEAR'])
rate = list(df['AVG avg_interest_among_all_matuarity'])
plt.bar(year,rate)
plt.xlabel("YEAR")
plt.ylabel("AVG avg interest among all matuarity Domain")
plt.title('The Treasury Breakeven Inflation (TBI) Curve')
plt.show()

# %%
plt.pie(rate, labels=year, 
    autopct='%1.1f%%', shadow=True, startangle=140)
plt.title("The Treasury Breakeven Inflation (TBI) Curve")
plt.show()

# %%
plt.plot(year,rate,color = 'b',linewidth=5, alpha=0.7)
plt.xlabel("YEAR")
plt.ylabel("AVG avg interest among all matuarity Domain")
plt.title("The Treasury Breakeven Inflation (TBI) Curve")
plt.show()
